# %%
import pymongo

conn_str = 'mongodb://localhost:27017/LayItOut'
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=60000)

print(client.server_info())

# %%
db = client.get_database('LayItOut')

# %%
from datetime import datetime
import doctest

start_time = datetime(2022, 6, 4, 10, 0, 0)
exp_list = [
    'yaml-list', 'let-stmt', 'match-case', 'haskell-do',
    'python-for', 'where-assign', 'yaml-map', 'python-while-list'
]
users = ['0401', '0402', '0403', '0404', '0301', '0302', '0303', '0304']

def is_manual(uid: str, exp_id: int):
    """Check if the user of uid should do a manual experiment on exp# exp_id (0..7)
    
    >>> is_manual('0401', 0)
    True
    >>> is_manual('0402', 4)
    False
    >>> is_manual('0302', 0)
    False
    >>> is_manual('0303', 6)
    True
    """
    
    return bool((int(uid[3]) ^ exp_id) & 1)

doctest.testmod()

# %%
import itertools

manual_cases = list(map(lambda y: (y[0], y[1], exp_list[y[1]]), filter(lambda x: is_manual(x[0], x[1]), itertools.product(users, range(8)))))

# %%
len(manual_cases)

# %% [markdown]
# ### Manual
#
# - take the last submission on each grammar
# - time on disambiguating = time of last submission - time of first refinement

# %%
manual_results = []

for uid, case_id, case in manual_cases:
    # if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    metrics = list(db.metricManual.find({
        "uid": uid,
        "createdAt": {"$gte": start_time},
        "grammar": case,
    }).sort("createdAt", pymongo.ASCENDING))
    result_grammar = list(db.ebnf.find({
        "uid": uid,
        "createdAt": {"$gte": metrics[-1]['createdAt']}
    }).sort("createdAt", pymongo.ASCENDING).limit(1))[0]
    manual_results.append((uid, case, result_grammar['grammarName'], result_grammar['createdAt'] - metrics[0]['createdAt']))

# %%
manual_results[0], len(manual_results)

# %%
import pathlib

results_root = pathlib.Path("./results/2022-06-04")
results_root.mkdir(parents=True, exist_ok=True)

# %%
manual_root = results_root / "manual"
manual_root.mkdir(exist_ok=True)

for uid, grammar, grammar_id, _ in manual_results:
    g = list(db.ebnf.find({"grammarName": grammar_id}).limit(1))[0]
    filename = f"{uid}_{grammar}.ebnf"
    with (manual_root / filename).open('w') as f:
        f.write(g['ebnf'])

# %%
# !ls "results/2022-06-04/manual"

# %%
db = client.get_database('LayItOut')

# %%
from datetime import datetime
import doctest

start_time = datetime(2022, 6, 4, 10, 0, 0)
exp_list = [
    'yaml-list', 'let-stmt', 'match-case', 'haskell-do',
    'python-for', 'where-assign', 'yaml-map', 'python-while-list'
]
users = ['0401', '0402', '0403', '0404', '0301', '0302', '0303', '0304']

def is_manual(uid: str, exp_id: int):
    """Check if the user of uid should do a manual experiment on exp# exp_id (0..7)
    
    >>> is_manual('0401', 0)
    True
    >>> is_manual('0402', 4)
    False
    >>> is_manual('0302', 0)
    False
    >>> is_manual('0303', 6)
    True
    """
    
    return bool((int(uid[3]) ^ exp_id) & 1)

doctest.testmod()

# %%
import itertools

manual_cases = list(map(lambda y: (y[0], y[1], exp_list[y[1]]), filter(lambda x: is_manual(x[0], x[1]), itertools.product(users, range(8)))))

# %%
len(manual_cases)

# %%
manual_results = []

for uid, case_id, case in manual_cases:
    # if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    metrics = list(db.metricManual.find({
        "uid": uid,
        "createdAt": {"$gte": start_time},
        "grammar": case,
    }).sort("createdAt", pymongo.ASCENDING))
    result_grammar = list(db.ebnf.find({
        "uid": uid,
        "createdAt": {"$gte": metrics[-1]['createdAt']}
    }).sort("createdAt", pymongo.ASCENDING).limit(1))[0]
    manual_results.append((uid, case, result_grammar['grammarName'], result_grammar['createdAt'] - metrics[0]['createdAt']))

# %%
manual_results[0], len(manual_results)

# %%
import pathlib

results_root = pathlib.Path("./results/2022-06-04")
results_root.mkdir(parents=True, exist_ok=True)

# %%
manual_root = results_root / "manual"
manual_root.mkdir(exist_ok=True)

for uid, grammar, grammar_id, _ in manual_results:
    g = list(db.ebnf.find({"grammarName": grammar_id}).limit(1))[0]
    filename = f"{uid}_{grammar}.ebnf"
    b = manual_root / filename
    with b.open('w') as f:
        f.write(g['ebnf'])

# %%
# !ls "results/2022-06-04/manual"

# %%
import os

check_ambiguity = True

ambig = []
for uid, grammar, _, _ in manual_results:
    print(uid, grammar)
    filename = f"{uid}_{grammar}.ebnf"
    res = os.system(f'python main.py -c 20 {str(manual_root / filename)}')
    ambig.append(res > 0)
    print(res > 0)

# %%
sum(ambig), len(ambig)

# %% [markdown]
# There're 6 out of 32 ambiguous results in manual cases.

# %%
list(filter(lambda x: x[1], zip(manual_results, ambig)))

# %% [markdown]
# #### P2, 0402, let-stmt, B2
#
# ```
# let-expr ::= ( ( ( "let"   decl |*|  ) >> )  "in"  expr  ) >> ;
# decl ::= (  expr  "="  expr  ) >> ;
# expr ::= "id" | ( "id"  "id"  ) >> | let-expr;
# ```
#
# #### P2, 0402, haskell-do, B4
#
# ```
# document ::= stmt |+| ;
# do-block ::= ( "do"  stmt |+| ) >> ;
# stmt ::= ( ( "main"  "="  do-block  ) >> ) | ( "putStrLn"  "id"  ) >>;
# ```
#
# #### P2, 0402, where-assign, B6
#
# ```
# document ::= assign-stmt |+|;
# assign-stmt ::= ( ( ( "id"  "="  expr  ) >> )  (  where ? )  ) >> ;
# where ::= ( "where" assign-stmt |+|  ) >> ;
# expr ::= ( "id"  "+"  "id"  ) ~ ;
# ```
#
# #### P3, 0403, yaml-map, B7
#
# ```
# map ::= ( ( "id"  ":"  ) ~   map-body  )|>;
# map-body ::= expl-or-impl-kv |+|;
# expl-kv ::= ( expl-k  expl-v?)|>;
# expl-k ::= ( "?"  k-or-v  ) >> ;
# expl-v ::= ( ":"  k-or-v  ) >> ;
# impl-kv ::= ( ( "id"  ":"  ) ~   "id"? ) ~ ;
# k-or-v ::= ( ( map-body | "id"  ) >> ) ? ;
# expl-or-impl-kv ::= expl-kv | impl-kv ;
# ```
#
# #### P8, 0304, haskell-do, B4
#
# ```
# document ::= stmt |+|;
# do-block ::= "do" -> (  stmt + );
# stmt ::= (  ( "main"  "="  )>>   do-block ) | ( "putStrLn"  "id"  )>>  ;
# ```
#
# #### P8, 0304, python-while-list, B8
#
# ```
# document ::=  stmt |+| ;
# stmt ::= "pass" | while-stmt | decl ;
# while-head ::= ( ( ( "while"  "True"  ) ~ )  ":"  ) ~ ;
# while-body-stmt ::= ( stmt | "break"  )>>;
# while-stmt ::= ( while-head  (  while-body-stmt + )  ) >> ;
# decl ::= ident  "="  list ;
# ident ::= ( "foo" | "bar"  | "baz" ) ~ ;
# list ::= ( (  "["   ( ( ident  ","  ) ~ ) *  ident  )>> "]"  )>>;
# ```

# %% [markdown]
# #### Inspection
#
# - 0401
#     - python-for: not enforcing sameline
# - 0402
#     - python-while-list: decl >>, too strict
#     - other 3 are ambiguous
# - 0403
#     - yaml-list: wrong. disallows cascading
#     - yaml-map: ambiguous
# - 0404
#     - all: excessive constraints
# - 0304
#     - let-stmt: too strict; contradicting constraints
#     - where-assign: too strict; contradicting constraints
#     - python-while-list: ambiguous

# %% [markdown]
# ### Disambiguation Time

# %%
from collections import defaultdict
from datetime import timedelta

manual_time_sum = defaultdict(list)

for k, v in map(lambda x: (x[1], x[3]), manual_results):
    manual_time_sum[k].append(v)

# %%
from statistics import *
from datetime import timedelta
from prettytable import PrettyTable

tbl_manual = PrettyTable()
tbl_manual.field_names = ["Grammar", "Average", "Median"]
tbl_manual.align = 'l'
tbl_manual.align['avg'] = tbl_manual.align['median'] = 'c'

for k in exp_list:
    v = manual_time_sum[k]
    tbl_manual.add_row([k, timedelta(seconds=int(fmean(map(lambda x: x.seconds, v)))), timedelta(seconds=int(median(v).seconds))])

print("Time for manual disambiguation of grammars")
print(tbl_manual)

# %% [markdown]
# **TODO: REMOVE TIME IN SUPPLEMENTARY MATERIAL**

# %% [markdown]
# ### Automatic
#
# - collect disambiguation time & final results

# %%
auto_cases = list(map(lambda y: (y[0], y[1], exp_list[y[1]]), filter(lambda x: not is_manual(x[0], x[1]), itertools.product(users, range(8)))))

# %%
len(auto_cases)

# %%
auto_results = []

for uid, case_id, case in auto_cases:
    #if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    #if uid == '0404' and case_id == 6: continue # failed case
    metrics = list(db.metricTool.find({
        "uid": uid,
        "createdAt": {"$gte": start_time},
        "grammar": {"$regex": r"^" + case + r"\[........\]_round_\d+$"}
    }).sort("createdAt", pymongo.ASCENDING).limit(1))
    first_metric = metrics[0]
    result_grammar = list(db.ebnf.find({
        "uid": uid,
        "grammarName": {"$regex": r"^" + case + r"\[........\]_round_\d+$"}
    }).sort("createdAt", pymongo.DESCENDING).limit(1))[0]
    auto_results.append((uid, case, result_grammar['grammarName'], result_grammar['createdAt'] - first_metric['createdAt']))

# %%
auto_results[0], len(auto_results)

# %%
auto_root = results_root / "auto"
auto_root.mkdir(exist_ok=True)

for uid, grammar, grammar_id, _ in auto_results:
    g = list(db.ebnf.find({"grammarName": grammar_id}).limit(1))[0]
    filename = f"{uid}_{grammar}.ebnf"
    b = auto_root / filename
    with b.open('w') as f:
        f.write(g['ebnf'])

# %%
# !ls "results/2022-06-04/auto/"

# %%
from collections import defaultdict
from datetime import timedelta

auto_time_sum = defaultdict(list)

for k, v in map(lambda x: (x[1], x[3]), auto_results):
    auto_time_sum[k].append(v)

# %%
from statistics import *
from datetime import timedelta
from prettytable import PrettyTable

tbl_auto = PrettyTable()
tbl_auto.field_names = ["Grammar", "Average", "Median"]
tbl_auto.align = 'l'
tbl_auto.align['avg'] = tbl_auto.align['median'] = 'c'

for k in exp_list:
    v = auto_time_sum[k]
    tbl_auto.add_row([k, timedelta(seconds=int(fmean(map(lambda x: x.seconds, v)))), timedelta(seconds=int(median(v).seconds))])

print("Time for auto disambiguation of grammars")
print(tbl_auto)

# %%
auto_time_sum['python-while-list']

# %%
sum(auto_time_sum['python-while-list'], start=timedelta(0)) / 4

# %% [markdown]
# #### Inspection
# - 0401
#     - let-stmt: too strict, excluding examples
# - 0402
#     - yaml-list: wrong. disallows cascading
# - 0403
#     - haskell-do: excessive constraints
#     - let-stmt: too strict, disallows cascading
#     - python-while-list: too strict, excluding examples
#     - where-assign: might be too strict, differs from examples given
# - 0404
#     - match-case: too weak? not requiring match -> cases
#     - python-for: exc. cons.
#     - yaml-list: exc. cons.
# - 0301
#     - where-assign: might be too strict, differs from examples given
# - 0303
#     - python-while-list: excluding examples
#     - where-assign: exc. cons.
# - 0304
#     - python-for: exc. cons.
#     - yaml-map: wrong. disallows cascading

# %% [markdown]
# #### Iteration Count

# %%
for uid, case_id, case in auto_cases:
    #if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    #if uid == '0404' and case_id == 6: continue # failed case
    grammars = list(db.ebnf.find({
        "uid": uid,
        "grammarName": {"$regex": r"^" + case + r"\[........\]_round_\d+$"}
    }).sort("createdAt", pymongo.ASCENDING))
    print(uid, case, len(grammars))

# %% [markdown]
# ### Paper Writing
#
# #### time (?)
#
# - imperfect ui design?
# - iteration cnt?
#
# #### disambiguation
#
# - 5 / 28: effectiveness
# - questionaire results
#
# **Metrics on time are not accurate**

# %%
6/32

# %%
db = client.get_database('LayItOut')

# %%
from datetime import datetime
import doctest

start_time = datetime(2022, 6, 4, 10, 0, 0)
exp_list = [
    'yaml-list', 'let-stmt', 'match-case', 'haskell-do',
    'python-for', 'where-assign', 'yaml-map', 'python-while-list'
]
users = ['0401', '0402', '0403', '0404', '0301', '0302', '0303', '0304']

def is_manual(uid: str, exp_id: int):
    """Check if the user of uid should do a manual experiment on exp# exp_id (0..7)
    
    >>> is_manual('0401', 0)
    True
    >>> is_manual('0402', 4)
    False
    >>> is_manual('0302', 0)
    False
    >>> is_manual('0303', 6)
    True
    """
    
    return bool((int(uid[3]) ^ exp_id) & 1)

doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %%
import itertools

manual_cases = list(map(lambda y: (y[0], y[1], exp_list[y[1]]), filter(lambda x: is_manual(x[0], x[1]), itertools.product(users, range(8)))))

# %%
len(manual_cases)
# Out:
# 32

# %% [markdown]
# ### Manual
#
# - take the last submission on each grammar
# - time on disambiguating = time of last submission - time of first refinement

# %%
manual_results = []

for uid, case_id, case in manual_cases:
    # if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    metrics = list(db.metricManual.find({
        "uid": uid,
        "createdAt": {"$gte": start_time},
        "grammar": case,
    }).sort("createdAt", pymongo.ASCENDING))
    result_grammar = list(db.ebnf.find({
        "uid": uid,
        "createdAt": {"$gte": metrics[-1]['createdAt']}
    }).sort("createdAt", pymongo.ASCENDING).limit(1))[0]
    manual_results.append((uid, case, result_grammar['grammarName'], result_grammar['createdAt'] - metrics[0]['createdAt']))

# %%
manual_results[0], len(manual_results)
# Out:
# (('0401',
#   'yaml-list',
#   '__S5pW-DgBHZ7MiLjsamN9x',
#   datetime.timedelta(seconds=162)),
#  32)

# %%
import pathlib

results_root = pathlib.Path("./results/2022-06-04")
results_root.mkdir(parents=True, exist_ok=True)

# %%
manual_root = results_root / "manual"
manual_root.mkdir(exist_ok=True)

for uid, grammar, grammar_id, _ in manual_results:
    g = list(db.ebnf.find({"grammarName": grammar_id}).limit(1))[0]
    filename = f"{uid}_{grammar}.ebnf"
    with (manual_root / filename).open('w') as f:
        f.write(g['ebnf'])

# %%
# !ls "results/2022-06-04/manual"
# Out:
# 0301_match-case.ebnf	     0401_match-case.ebnf
# 0301_python-for.ebnf	     0401_python-for.ebnf
# 0301_yaml-list.ebnf	     0401_yaml-list.ebnf
# 0301_yaml-map.ebnf	     0401_yaml-map.ebnf
# 0302_haskell-do.ebnf	     0402_haskell-do.ebnf
# 0302_let-stmt.ebnf	     0402_let-stmt.ebnf
# 0302_python-while-list.ebnf  0402_python-while-list.ebnf
# 0302_where-assign.ebnf	     0402_where-assign.ebnf
# 0303_match-case.ebnf	     0403_match-case.ebnf
# 0303_python-for.ebnf	     0403_python-for.ebnf
# 0303_yaml-list.ebnf	     0403_yaml-list.ebnf
# 0303_yaml-map.ebnf	     0403_yaml-map.ebnf
# 0304_haskell-do.ebnf	     0404_haskell-do.ebnf
# 0304_let-stmt.ebnf	     0404_let-stmt.ebnf
# 0304_python-while-list.ebnf  0404_python-while-list.ebnf
# 0304_where-assign.ebnf	     0404_where-assign.ebnf

# %%
db = client.get_database('LayItOut')

# %%
from datetime import datetime
import doctest

start_time = datetime(2022, 6, 4, 10, 0, 0)
exp_list = [
    'yaml-list', 'let-stmt', 'match-case', 'haskell-do',
    'python-for', 'where-assign', 'yaml-map', 'python-while-list'
]
users = ['0401', '0402', '0403', '0404', '0301', '0302', '0303', '0304']

def is_manual(uid: str, exp_id: int):
    """Check if the user of uid should do a manual experiment on exp# exp_id (0..7)
    
    >>> is_manual('0401', 0)
    True
    >>> is_manual('0402', 4)
    False
    >>> is_manual('0302', 0)
    False
    >>> is_manual('0303', 6)
    True
    """
    
    return bool((int(uid[3]) ^ exp_id) & 1)

doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %%
import itertools

manual_cases = list(map(lambda y: (y[0], y[1], exp_list[y[1]]), filter(lambda x: is_manual(x[0], x[1]), itertools.product(users, range(8)))))

# %%
len(manual_cases)
# Out:
# 32

# %%
manual_results = []

for uid, case_id, case in manual_cases:
    # if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    metrics = list(db.metricManual.find({
        "uid": uid,
        "createdAt": {"$gte": start_time},
        "grammar": case,
    }).sort("createdAt", pymongo.ASCENDING))
    result_grammar = list(db.ebnf.find({
        "uid": uid,
        "createdAt": {"$gte": metrics[-1]['createdAt']}
    }).sort("createdAt", pymongo.ASCENDING).limit(1))[0]
    manual_results.append((uid, case, result_grammar['grammarName'], result_grammar['createdAt'] - metrics[0]['createdAt']))

# %%
manual_results[0], len(manual_results)
# Out:
# (('0401',
#   'yaml-list',
#   '__S5pW-DgBHZ7MiLjsamN9x',
#   datetime.timedelta(seconds=162)),
#  32)

# %%
import pathlib

results_root = pathlib.Path("./results/2022-06-04")
results_root.mkdir(parents=True, exist_ok=True)

# %%
manual_root = results_root / "manual"
manual_root.mkdir(exist_ok=True)

for uid, grammar, grammar_id, _ in manual_results:
    g = list(db.ebnf.find({"grammarName": grammar_id}).limit(1))[0]
    filename = f"{uid}_{grammar}.ebnf"
    b = manual_root / filename
    with b.open('w') as f:
        f.write(g['ebnf'])

# %%
# !ls "results/2022-06-04/manual"
# Out:
# 0301_match-case.ebnf	     0401_match-case.ebnf
# 0301_python-for.ebnf	     0401_python-for.ebnf
# 0301_yaml-list.ebnf	     0401_yaml-list.ebnf
# 0301_yaml-map.ebnf	     0401_yaml-map.ebnf
# 0302_haskell-do.ebnf	     0402_haskell-do.ebnf
# 0302_let-stmt.ebnf	     0402_let-stmt.ebnf
# 0302_python-while-list.ebnf  0402_python-while-list.ebnf
# 0302_where-assign.ebnf	     0402_where-assign.ebnf
# 0303_match-case.ebnf	     0403_match-case.ebnf
# 0303_python-for.ebnf	     0403_python-for.ebnf
# 0303_yaml-list.ebnf	     0403_yaml-list.ebnf
# 0303_yaml-map.ebnf	     0403_yaml-map.ebnf
# 0304_haskell-do.ebnf	     0404_haskell-do.ebnf
# 0304_let-stmt.ebnf	     0404_let-stmt.ebnf
# 0304_python-while-list.ebnf  0404_python-while-list.ebnf
# 0304_where-assign.ebnf	     0404_where-assign.ebnf

# %%
import os

check_ambiguity = True

ambig = []
for uid, grammar, _, _ in manual_results:
    print(uid, grammar)
    filename = f"{uid}_{grammar}.ebnf"
    res = os.system(f'python main.py -c 20 {str(manual_root / filename)}')
    ambig.append(res > 0)
    print(res > 0)
# Out:
# 0401 yaml-list
# Now checking witness sentences of length 1...
# SMT variable count is 33.
# extend_triple_array_by_one took 0.001592 second(s).
# extend_increasing_condition_by_one took 0.005529 second(s).
# extend_symbol_bound_by_one took 0.000281 second(s).
# AST of the assertion deductive contains 58 nodes.
# extend_deductive_condition_by_one took 0.003016 second(s).
# AST of the assertion ambiguity contains 76 nodes.
# build_ambiguity_condition took 0.002344 second(s).
# solve took 0.000212 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 86.
# extend_triple_array_by_one took 0.001647 second(s).
# extend_increasing_condition_by_one took 0.000474 second(s).
# extend_symbol_bound_by_one took 0.000218 second(s).
# AST of the assertion deductive contains 186 nodes.
# extend_deductive_condition_by_one took 0.004186 second(s).
# AST of the assertion ambiguity contains 290 nodes.
# build_ambiguity_condition took 0.004436 second(s).
# solve took 0.000433 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 159.
# extend_triple_array_by_one took 0.001887 second(s).
# extend_increasing_condition_by_one took 0.000488 second(s).
# extend_symbol_bound_by_one took 0.000263 second(s).
# AST of the assertion deductive contains 404 nodes.
# extend_deductive_condition_by_one took 0.005989 second(s).
# AST of the assertion ambiguity contains 686 nodes.
# build_ambiguity_condition took 0.007794 second(s).
# solve took 0.001195 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 252.
# extend_triple_array_by_one took 0.002109 second(s).
# extend_increasing_condition_by_one took 0.000503 second(s).
# extend_symbol_bound_by_one took 0.000240 second(s).
# AST of the assertion deductive contains 732 nodes.
# extend_deductive_condition_by_one took 0.007195 second(s).
# AST of the assertion ambiguity contains 1308 nodes.
# build_ambiguity_condition took 0.011998 second(s).
# solve took 0.002857 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 365.
# extend_triple_array_by_one took 0.002027 second(s).
# extend_increasing_condition_by_one took 0.000382 second(s).
# extend_symbol_bound_by_one took 0.000176 second(s).
# AST of the assertion deductive contains 1190 nodes.
# extend_deductive_condition_by_one took 0.008721 second(s).
# AST of the assertion ambiguity contains 2200 nodes.
# build_ambiguity_condition took 0.018704 second(s).
# solve took 0.007130 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 498.
# extend_triple_array_by_one took 0.002071 second(s).
# extend_increasing_condition_by_one took 0.000369 second(s).
# extend_symbol_bound_by_one took 0.000260 second(s).
# AST of the assertion deductive contains 1798 nodes.
# extend_deductive_condition_by_one took 0.010607 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# AST of the assertion ambiguity contains 3406 nodes.
# build_ambiguity_condition took 0.052824 second(s).
# solve took 0.022639 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 651.
# extend_triple_array_by_one took 0.002496 second(s).
# extend_increasing_condition_by_one took 0.000742 second(s).
# extend_symbol_bound_by_one took 0.000273 second(s).
# AST of the assertion deductive contains 2576 nodes.
# extend_deductive_condition_by_one took 0.015256 second(s).
# AST of the assertion ambiguity contains 4970 nodes.
# build_ambiguity_condition took 0.038002 second(s).
# solve took 0.032781 second(s).
# Now checking witness sentences of length 8...
# SMT variable count is 824.
# extend_triple_array_by_one took 0.002804 second(s).
# extend_increasing_condition_by_one took 0.000422 second(s).
# extend_symbol_bound_by_one took 0.000201 second(s).
# AST of the assertion deductive contains 3544 nodes.
# extend_deductive_condition_by_one took 0.014639 second(s).
# AST of the assertion ambiguity contains 6936 nodes.
# build_ambiguity_condition took 0.052043 second(s).
# solve took 0.068650 second(s).
# Now checking witness sentences of length 9...
# SMT variable count is 1017.
# extend_triple_array_by_one took 0.002510 second(s).
# extend_increasing_condition_by_one took 0.000395 second(s).
# extend_symbol_bound_by_one took 0.000174 second(s).
# AST of the assertion deductive contains 4722 nodes.
# extend_deductive_condition_by_one took 0.016862 second(s).
# AST of the assertion ambiguity contains 9348 nodes.
# build_ambiguity_condition took 0.066504 second(s).
# solve took 0.146579 second(s).
# Now checking witness sentences of length 10...
# SMT variable count is 1230.
# extend_triple_array_by_one took 0.002652 second(s).
# extend_increasing_condition_by_one took 0.000417 second(s).
# extend_symbol_bound_by_one took 0.000176 second(s).
# AST of the assertion deductive contains 6130 nodes.
# extend_deductive_condition_by_one took 0.018855 second(s).
# AST of the assertion ambiguity contains 12250 nodes.
# build_ambiguity_condition took 0.121053 second(s).
# solve took 0.354899 second(s).
# Now checking witness sentences of length 11...
# SMT variable count is 1463.
# extend_triple_array_by_one took 0.002935 second(s).
# extend_increasing_condition_by_one took 0.000483 second(s).
# extend_symbol_bound_by_one took 0.000181 second(s).
# AST of the assertion deductive contains 7788 nodes.
# extend_deductive_condition_by_one took 0.021351 second(s).
# AST of the assertion ambiguity contains 15686 nodes.
# build_ambiguity_condition took 0.107914 second(s).
# solve took 0.515704 second(s).
# Now checking witness sentences of length 12...
# SMT variable count is 1716.
# extend_triple_array_by_one took 0.003136 second(s).
# extend_increasing_condition_by_one took 0.000557 second(s).
# extend_symbol_bound_by_one took 0.000251 second(s).
# AST of the assertion deductive contains 9716 nodes.
# extend_deductive_condition_by_one took 0.026151 second(s).
# AST of the assertion ambiguity contains 19700 nodes.
# build_ambiguity_condition took 0.191668 second(s).
# solve took 0.802059 second(s).
# Now checking witness sentences of length 13...
# SMT variable count is 1989.
# extend_triple_array_by_one took 0.003088 second(s).
# extend_increasing_condition_by_one took 0.000408 second(s).
# extend_symbol_bound_by_one took 0.000185 second(s).
# AST of the assertion deductive contains 11934 nodes.
# extend_deductive_condition_by_one took 0.027294 second(s).
# AST of the assertion ambiguity contains 24336 nodes.
# build_ambiguity_condition took 0.213393 second(s).
# solve took 2.413475 second(s).
# Now checking witness sentences of length 14...
# SMT variable count is 2282.
# extend_triple_array_by_one took 0.003312 second(s).
# extend_increasing_condition_by_one took 0.000418 second(s).
# extend_symbol_bound_by_one took 0.000156 second(s).
# AST of the assertion deductive contains 14462 nodes.
# extend_deductive_condition_by_one took 0.029880 second(s).
# AST of the assertion ambiguity contains 29638 nodes.
# build_ambiguity_condition took 0.194334 second(s).
# solve took 2.951826 second(s).
# Now checking witness sentences of length 15...
# SMT variable count is 2595.
# extend_triple_array_by_one took 0.003879 second(s).
# extend_increasing_condition_by_one took 0.000513 second(s).
# extend_symbol_bound_by_one took 0.000333 second(s).
# AST of the assertion deductive contains 17320 nodes.
# extend_deductive_condition_by_one took 0.033344 second(s).
# AST of the assertion ambiguity contains 35650 nodes.
# build_ambiguity_condition took 0.237498 second(s).
# solve took 4.422048 second(s).
# Now checking witness sentences of length 16...
# SMT variable count is 2928.
# extend_triple_array_by_one took 0.003518 second(s).
# extend_increasing_condition_by_one took 0.000447 second(s).
# extend_symbol_bound_by_one took 0.000190 second(s).
# AST of the assertion deductive contains 20528 nodes.
# extend_deductive_condition_by_one took 0.037360 second(s).
# AST of the assertion ambiguity contains 42416 nodes.
# build_ambiguity_condition took 0.355873 second(s).
# solve took 6.336967 second(s).
# Now checking witness sentences of length 17...
# SMT variable count is 3281.
# extend_triple_array_by_one took 0.003846 second(s).
# extend_increasing_condition_by_one took 0.000476 second(s).
# extend_symbol_bound_by_one took 0.000222 second(s).
# AST of the assertion deductive contains 24106 nodes.
# extend_deductive_condition_by_one took 0.039407 second(s).
# AST of the assertion ambiguity contains 49980 nodes.
# build_ambiguity_condition took 0.409874 second(s).
# solve took 6.828777 second(s).
# Now checking witness sentences of length 18...
# SMT variable count is 3654.
# extend_triple_array_by_one took 0.003942 second(s).
# extend_increasing_condition_by_one took 0.000487 second(s).
# extend_symbol_bound_by_one took 0.000164 second(s).
# AST of the assertion deductive contains 28074 nodes.
# extend_deductive_condition_by_one took 0.041962 second(s).
# AST of the assertion ambiguity contains 58386 nodes.
# build_ambiguity_condition took 0.431091 second(s).
# solve took 12.275573 second(s).
# Now checking witness sentences of length 19...
# SMT variable count is 4047.
# extend_triple_array_by_one took 0.003983 second(s).
# extend_increasing_condition_by_one took 0.000461 second(s).
# extend_symbol_bound_by_one took 0.000192 second(s).
# AST of the assertion deductive contains 32452 nodes.
# extend_deductive_condition_by_one took 0.053007 second(s).
# AST of the assertion ambiguity contains 67678 nodes.
# build_ambiguity_condition took 0.438269 second(s).
# solve took 22.381509 second(s).
# Now checking witness sentences of length 20...
# SMT variable count is 4460.
# extend_triple_array_by_one took 0.004366 second(s).
# extend_increasing_condition_by_one took 0.000508 second(s).
# extend_symbol_bound_by_one took 0.000197 second(s).
# AST of the assertion deductive contains 37260 nodes.
# extend_deductive_condition_by_one took 0.053797 second(s).
# AST of the assertion ambiguity contains 77900 nodes.
# build_ambiguity_condition took 0.617564 second(s).
# solve took 33.718439 second(s).
# False
# 0401 match-case
# Now checking witness sentences of length 1...
# SMT variable count is 60.
# extend_triple_array_by_one took 0.001786 second(s).
# extend_increasing_condition_by_one took 0.005555 second(s).
# extend_symbol_bound_by_one took 0.000348 second(s).
# AST of the assertion deductive contains 103 nodes.
# extend_deductive_condition_by_one took 0.004162 second(s).
# AST of the assertion ambiguity contains 103 nodes.
# build_ambiguity_condition took 0.002558 second(s).
# solve took 0.000177 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 158.
# extend_triple_array_by_one took 0.001999 second(s).
# extend_increasing_condition_by_one took 0.000448 second(s).
# extend_symbol_bound_by_one took 0.000247 second(s).
# AST of the assertion deductive contains 338 nodes.
# extend_deductive_condition_by_one took 0.006172 second(s).
# AST of the assertion ambiguity contains 309 nodes.
# build_ambiguity_condition took 0.004966 second(s).
# solve took 0.000210 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 294.
# extend_triple_array_by_one took 0.002289 second(s).
# extend_increasing_condition_by_one took 0.000386 second(s).
# extend_symbol_bound_by_one took 0.000306 second(s).
# AST of the assertion deductive contains 762 nodes.
# extend_deductive_condition_by_one took 0.009102 second(s).
# AST of the assertion ambiguity contains 872 nodes.
# build_ambiguity_condition took 0.010298 second(s).
# solve took 0.000780 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 468.
# extend_triple_array_by_one took 0.002420 second(s).
# extend_increasing_condition_by_one took 0.000408 second(s).
# extend_symbol_bound_by_one took 0.000330 second(s).
# AST of the assertion deductive contains 1432 nodes.
# extend_deductive_condition_by_one took 0.012136 second(s).
# AST of the assertion ambiguity contains 1952 nodes.
# build_ambiguity_condition took 0.018043 second(s).
# solve took 0.002642 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 680.
# extend_triple_array_by_one took 0.002823 second(s).
# extend_increasing_condition_by_one took 0.000435 second(s).
# extend_symbol_bound_by_one took 0.000227 second(s).
# AST of the assertion deductive contains 2405 nodes.
# extend_deductive_condition_by_one took 0.015962 second(s).
# AST of the assertion ambiguity contains 3709 nodes.
# build_ambiguity_condition took 0.029040 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# solve took 0.006497 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 930.
# extend_triple_array_by_one took 0.003045 second(s).
# extend_increasing_condition_by_one took 0.000453 second(s).
# extend_symbol_bound_by_one took 0.000284 second(s).
# AST of the assertion deductive contains 3738 nodes.
# extend_deductive_condition_by_one took 0.019909 second(s).
# AST of the assertion ambiguity contains 6303 nodes.
# build_ambiguity_condition took 0.045778 second(s).
# solve took 0.017983 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 1218.
# extend_triple_array_by_one took 0.003286 second(s).
# extend_increasing_condition_by_one took 0.000518 second(s).
# extend_symbol_bound_by_one took 0.000268 second(s).
# AST of the assertion deductive contains 5488 nodes.
# extend_deductive_condition_by_one took 0.024224 second(s).
# AST of the assertion ambiguity contains 9894 nodes.
# build_ambiguity_condition took 0.067601 second(s).
# solve took 0.035405 second(s).
# Now checking witness sentences of length 8...
# SMT variable count is 1544.
# extend_triple_array_by_one took 0.003441 second(s).
# extend_increasing_condition_by_one took 0.000464 second(s).
# extend_symbol_bound_by_one took 0.000235 second(s).
# AST of the assertion deductive contains 7712 nodes.
# extend_deductive_condition_by_one took 0.029832 second(s).
# AST of the assertion ambiguity contains 14642 nodes.
# build_ambiguity_condition took 0.097502 second(s).
# solve took 0.070051 second(s).
# Now checking witness sentences of length 9...
# SMT variable count is 1908.
# extend_triple_array_by_one took 0.003977 second(s).
# extend_increasing_condition_by_one took 0.000513 second(s).
# extend_symbol_bound_by_one took 0.000293 second(s).
# AST of the assertion deductive contains 10467 nodes.
# extend_deductive_condition_by_one took 0.035035 second(s).
# AST of the assertion ambiguity contains 20707 nodes.
# build_ambiguity_condition took 0.132802 second(s).
# solve took 0.110305 second(s).
# Now checking witness sentences of length 10...
# SMT variable count is 2310.
# extend_triple_array_by_one took 0.004137 second(s).
# extend_increasing_condition_by_one took 0.000505 second(s).
# extend_symbol_bound_by_one took 0.000270 second(s).
# AST of the assertion deductive contains 13810 nodes.
# extend_deductive_condition_by_one took 0.039468 second(s).
# AST of the assertion ambiguity contains 28249 nodes.
# build_ambiguity_condition took 0.221278 second(s).
# solve took 0.195326 second(s).
# Now checking witness sentences of length 11...
# SMT variable count is 2750.
# extend_triple_array_by_one took 0.005079 second(s).
# extend_increasing_condition_by_one took 0.000496 second(s).
# extend_symbol_bound_by_one took 0.000234 second(s).
# AST of the assertion deductive contains 17798 nodes.
# extend_deductive_condition_by_one took 0.047578 second(s).
# AST of the assertion ambiguity contains 37428 nodes.
# build_ambiguity_condition took 0.320642 second(s).
# solve took 0.337839 second(s).
# Now checking witness sentences of length 12...
# SMT variable count is 3228.
# extend_triple_array_by_one took 0.004607 second(s).
# extend_increasing_condition_by_one took 0.000533 second(s).
# extend_symbol_bound_by_one took 0.000262 second(s).
# AST of the assertion deductive contains 22488 nodes.
# extend_deductive_condition_by_one took 0.051951 second(s).
# AST of the assertion ambiguity contains 48404 nodes.
# build_ambiguity_condition took 0.355616 second(s).
# solve took 0.500217 second(s).
# Now checking witness sentences of length 13...
# SMT variable count is 3744.
# extend_triple_array_by_one took 0.004863 second(s).
# extend_increasing_condition_by_one took 0.000480 second(s).
# extend_symbol_bound_by_one took 0.000241 second(s).
# AST of the assertion deductive contains 27937 nodes.
# extend_deductive_condition_by_one took 0.060289 second(s).
# AST of the assertion ambiguity contains 61337 nodes.
# build_ambiguity_condition took 0.434449 second(s).
# solve took 0.801871 second(s).
# Now checking witness sentences of length 14...
# SMT variable count is 4298.
# extend_triple_array_by_one took 0.005493 second(s).
# extend_increasing_condition_by_one took 0.000497 second(s).
# extend_symbol_bound_by_one took 0.000206 second(s).
# AST of the assertion deductive contains 34202 nodes.
# extend_deductive_condition_by_one took 0.064345 second(s).
# AST of the assertion ambiguity contains 76387 nodes.
# build_ambiguity_condition took 0.535045 second(s).
# solve took 1.132437 second(s).
# Now checking witness sentences of length 15...
# SMT variable count is 4890.
# extend_triple_array_by_one took 0.005584 second(s).
# extend_increasing_condition_by_one took 0.000456 second(s).
# extend_symbol_bound_by_one took 0.000189 second(s).
# AST of the assertion deductive contains 41340 nodes.
# extend_deductive_condition_by_one took 0.073686 second(s).
# AST of the assertion ambiguity contains 93714 nodes.
# build_ambiguity_condition took 0.661810 second(s).
# solve took 1.757764 second(s).
# Now checking witness sentences of length 16...
# SMT variable count is 5520.
# extend_triple_array_by_one took 0.005872 second(s).
# extend_increasing_condition_by_one took 0.000462 second(s).
# extend_symbol_bound_by_one took 0.000172 second(s).
# AST of the assertion deductive contains 49408 nodes.
# extend_deductive_condition_by_one took 0.083833 second(s).
# AST of the assertion ambiguity contains 113478 nodes.
# build_ambiguity_condition took 0.820185 second(s).
# solve took 2.607310 second(s).
# Now checking witness sentences of length 17...
# SMT variable count is 6188.
# extend_triple_array_by_one took 0.005937 second(s).
# extend_increasing_condition_by_one took 0.000485 second(s).
# extend_symbol_bound_by_one took 0.000168 second(s).
# AST of the assertion deductive contains 58463 nodes.
# extend_deductive_condition_by_one took 0.087699 second(s).
# AST of the assertion ambiguity contains 135839 nodes.
# build_ambiguity_condition took 0.932714 second(s).
# solve took 3.762875 second(s).
# Now checking witness sentences of length 18...
# SMT variable count is 6894.
# extend_triple_array_by_one took 0.006683 second(s).
# extend_increasing_condition_by_one took 0.000466 second(s).
# extend_symbol_bound_by_one took 0.000159 second(s).
# AST of the assertion deductive contains 68562 nodes.
# extend_deductive_condition_by_one took 0.097204 second(s).
# AST of the assertion ambiguity contains 160957 nodes.
# build_ambiguity_condition took 1.132439 second(s).
# solve took 5.229063 second(s).
# Now checking witness sentences of length 19...
# SMT variable count is 7638.
# extend_triple_array_by_one took 0.006364 second(s).
# extend_increasing_condition_by_one took 0.000466 second(s).
# extend_symbol_bound_by_one took 0.000153 second(s).
# AST of the assertion deductive contains 79762 nodes.
# extend_deductive_condition_by_one took 0.105168 second(s).
# AST of the assertion ambiguity contains 188992 nodes.
# build_ambiguity_condition took 1.324920 second(s).
# solve took 6.858250 second(s).
# Now checking witness sentences of length 20...
# SMT variable count is 8420.
# extend_triple_array_by_one took 0.006929 second(s).
# extend_increasing_condition_by_one took 0.000439 second(s).
# extend_symbol_bound_by_one took 0.000154 second(s).
# AST of the assertion deductive contains 92120 nodes.
# extend_deductive_condition_by_one took 0.114506 second(s).
# AST of the assertion ambiguity contains 220104 nodes.
# build_ambiguity_condition took 1.497511 second(s).
# solve took 8.866289 second(s).
# False
# 0401 python-for
# Now checking witness sentences of length 1...
# SMT variable count is 72.
# extend_triple_array_by_one took 0.001860 second(s).
# extend_increasing_condition_by_one took 0.005446 second(s).
# extend_symbol_bound_by_one took 0.000235 second(s).
# AST of the assertion deductive contains 121 nodes.
# extend_deductive_condition_by_one took 0.004578 second(s).
# AST of the assertion ambiguity contains 138 nodes.
# build_ambiguity_condition took 0.002849 second(s).
# solve took 0.000206 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 190.
# extend_triple_array_by_one took 0.002054 second(s).
# extend_increasing_condition_by_one took 0.000366 second(s).
# extend_symbol_bound_by_one took 0.000199 second(s).
# AST of the assertion deductive contains 386 nodes.
# extend_deductive_condition_by_one took 0.006691 second(s).
# AST of the assertion ambiguity contains 472 nodes.
# build_ambiguity_condition took 0.006153 second(s).
# solve took 0.000377 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 354.
# extend_triple_array_by_one took 0.002449 second(s).
# extend_increasing_condition_by_one took 0.000358 second(s).
# extend_symbol_bound_by_one took 0.000224 second(s).
# AST of the assertion deductive contains 850 nodes.
# extend_deductive_condition_by_one took 0.010258 second(s).
# AST of the assertion ambiguity contains 1296 nodes.
# build_ambiguity_condition took 0.012775 second(s).
# solve took 0.001484 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 564.
# extend_triple_array_by_one took 0.002676 second(s).
# extend_increasing_condition_by_one took 0.000346 second(s).
# extend_symbol_bound_by_one took 0.000212 second(s).
# AST of the assertion deductive contains 1568 nodes.
# extend_deductive_condition_by_one took 0.013545 second(s).
# AST of the assertion ambiguity contains 2810 nodes.
# build_ambiguity_condition took 0.023246 second(s).
# solve took 0.005062 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 820.
# extend_triple_array_by_one took 0.002943 second(s).
# extend_increasing_condition_by_one took 0.000368 second(s).
# extend_symbol_bound_by_one took 0.000183 second(s).
# AST of the assertion deductive contains 2595 nodes.
# extend_deductive_condition_by_one took 0.017953 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# AST of the assertion ambiguity contains 5214 nodes.
# build_ambiguity_condition took 0.063972 second(s).
# solve took 0.015411 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 1122.
# extend_triple_array_by_one took 0.003278 second(s).
# extend_increasing_condition_by_one took 0.000404 second(s).
# extend_symbol_bound_by_one took 0.000170 second(s).
# AST of the assertion deductive contains 3986 nodes.
# extend_deductive_condition_by_one took 0.022320 second(s).
# AST of the assertion ambiguity contains 8708 nodes.
# build_ambiguity_condition took 0.060693 second(s).
# solve took 0.043129 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 1470.
# extend_triple_array_by_one took 0.003684 second(s).
# extend_increasing_condition_by_one took 0.000492 second(s).
# extend_symbol_bound_by_one took 0.000232 second(s).
# AST of the assertion deductive contains 5796 nodes.
# extend_deductive_condition_by_one took 0.028968 second(s).
# AST of the assertion ambiguity contains 13492 nodes.
# build_ambiguity_condition took 0.089183 second(s).
# solve took 0.078260 second(s).
# Now checking witness sentences of length 8...
# SMT variable count is 1864.
# extend_triple_array_by_one took 0.004171 second(s).
# extend_increasing_condition_by_one took 0.000444 second(s).
# extend_symbol_bound_by_one took 0.000234 second(s).
# AST of the assertion deductive contains 8080 nodes.
# extend_deductive_condition_by_one took 0.035816 second(s).
# AST of the assertion ambiguity contains 19766 nodes.
# build_ambiguity_condition took 0.177655 second(s).
# solve took 0.139433 second(s).
# Now checking witness sentences of length 9...
# SMT variable count is 2304.
# extend_triple_array_by_one took 0.004350 second(s).
# extend_increasing_condition_by_one took 0.000457 second(s).
# extend_symbol_bound_by_one took 0.000217 second(s).
# AST of the assertion deductive contains 10893 nodes.
# extend_deductive_condition_by_one took 0.039378 second(s).
# AST of the assertion ambiguity contains 27730 nodes.
# build_ambiguity_condition took 0.218244 second(s).
# solve took 0.240177 second(s).
# Now checking witness sentences of length 10...
# SMT variable count is 2790.
# extend_triple_array_by_one took 0.005154 second(s).
# extend_increasing_condition_by_one took 0.000470 second(s).
# extend_symbol_bound_by_one took 0.000199 second(s).
# AST of the assertion deductive contains 14290 nodes.
# extend_deductive_condition_by_one took 0.046110 second(s).
# AST of the assertion ambiguity contains 37584 nodes.
# build_ambiguity_condition took 0.283852 second(s).
# solve took 0.421281 second(s).
# Now checking witness sentences of length 11...
# SMT variable count is 3322.
# extend_triple_array_by_one took 0.004885 second(s).
# extend_increasing_condition_by_one took 0.000431 second(s).
# extend_symbol_bound_by_one took 0.000190 second(s).
# AST of the assertion deductive contains 18326 nodes.
# extend_deductive_condition_by_one took 0.053891 second(s).
# AST of the assertion ambiguity contains 49528 nodes.
# build_ambiguity_condition took 0.389146 second(s).
# solve took 0.717750 second(s).
# Now checking witness sentences of length 12...
# SMT variable count is 3900.
# extend_triple_array_by_one took 0.005780 second(s).
# extend_increasing_condition_by_one took 0.000475 second(s).
# extend_symbol_bound_by_one took 0.000239 second(s).
# AST of the assertion deductive contains 23056 nodes.
# extend_deductive_condition_by_one took 0.059825 second(s).
# AST of the assertion ambiguity contains 63762 nodes.
# build_ambiguity_condition took 0.454491 second(s).
# solve took 1.152825 second(s).
# Now checking witness sentences of length 13...
# SMT variable count is 4524.
# extend_triple_array_by_one took 0.006299 second(s).
# extend_increasing_condition_by_one took 0.000428 second(s).
# extend_symbol_bound_by_one took 0.000183 second(s).
# AST of the assertion deductive contains 28535 nodes.
# extend_deductive_condition_by_one took 0.067674 second(s).
# AST of the assertion ambiguity contains 80486 nodes.
# build_ambiguity_condition took 0.562859 second(s).
# solve took 1.726547 second(s).
# Now checking witness sentences of length 14...
# SMT variable count is 5194.
# extend_triple_array_by_one took 0.005902 second(s).
# extend_increasing_condition_by_one took 0.000456 second(s).
# extend_symbol_bound_by_one took 0.000165 second(s).
# AST of the assertion deductive contains 34818 nodes.
# extend_deductive_condition_by_one took 0.077590 second(s).
# AST of the assertion ambiguity contains 99900 nodes.
# build_ambiguity_condition took 0.700874 second(s).
# solve took 2.635186 second(s).
# Now checking witness sentences of length 15...
# SMT variable count is 5910.
# extend_triple_array_by_one took 0.006815 second(s).
# extend_increasing_condition_by_one took 0.000573 second(s).
# extend_symbol_bound_by_one took 0.000237 second(s).
# AST of the assertion deductive contains 41960 nodes.
# extend_deductive_condition_by_one took 0.088940 second(s).
# AST of the assertion ambiguity contains 122204 nodes.
# build_ambiguity_condition took 0.833658 second(s).
# solve took 3.933663 second(s).
# Now checking witness sentences of length 16...
# SMT variable count is 6672.
# extend_triple_array_by_one took 0.006607 second(s).
# extend_increasing_condition_by_one took 0.000482 second(s).
# extend_symbol_bound_by_one took 0.000183 second(s).
# AST of the assertion deductive contains 50016 nodes.
# extend_deductive_condition_by_one took 0.094897 second(s).
# AST of the assertion ambiguity contains 147598 nodes.
# build_ambiguity_condition took 1.002806 second(s).
# solve took 5.620713 second(s).
# Now checking witness sentences of length 17...
# SMT variable count is 7480.
# extend_triple_array_by_one took 0.006814 second(s).
# extend_increasing_condition_by_one took 0.000486 second(s).
# extend_symbol_bound_by_one took 0.000194 second(s).
# AST of the assertion deductive contains 59041 nodes.
# extend_deductive_condition_by_one took 0.103646 second(s).
# AST of the assertion ambiguity contains 176282 nodes.
# build_ambiguity_condition took 1.220942 second(s).
# solve took 8.005306 second(s).
# Now checking witness sentences of length 18...
# SMT variable count is 8334.
# extend_triple_array_by_one took 0.007423 second(s).
# extend_increasing_condition_by_one took 0.000557 second(s).
# extend_symbol_bound_by_one took 0.000213 second(s).
# AST of the assertion deductive contains 69090 nodes.
# extend_deductive_condition_by_one took 0.114972 second(s).
# AST of the assertion ambiguity contains 208456 nodes.
# build_ambiguity_condition took 1.408939 second(s).
# solve took 10.616906 second(s).
# Now checking witness sentences of length 19...
# SMT variable count is 9234.
# extend_triple_array_by_one took 0.007508 second(s).
# extend_increasing_condition_by_one took 0.000533 second(s).
# extend_symbol_bound_by_one took 0.000226 second(s).
# AST of the assertion deductive contains 80218 nodes.
# extend_deductive_condition_by_one took 0.123799 second(s).
# AST of the assertion ambiguity contains 244320 nodes.
# build_ambiguity_condition took 1.656585 second(s).
# solve took 14.636170 second(s).
# Now checking witness sentences of length 20...
# SMT variable count is 10180.
# extend_triple_array_by_one took 0.007972 second(s).
# extend_increasing_condition_by_one took 0.000516 second(s).
# extend_symbol_bound_by_one took 0.000160 second(s).
# AST of the assertion deductive contains 92480 nodes.
# extend_deductive_condition_by_one took 0.136786 second(s).
# AST of the assertion ambiguity contains 284074 nodes.
# build_ambiguity_condition took 1.972248 second(s).
# solve took 19.824162 second(s).
# False
# 0401 yaml-map
# Now checking witness sentences of length 1...
# SMT variable count is 84.
# extend_triple_array_by_one took 0.001986 second(s).
# extend_increasing_condition_by_one took 0.005612 second(s).
# extend_symbol_bound_by_one took 0.000268 second(s).
# AST of the assertion deductive contains 157 nodes.
# extend_deductive_condition_by_one took 0.005219 second(s).
# AST of the assertion ambiguity contains 150 nodes.
# build_ambiguity_condition took 0.003359 second(s).
# solve took 0.000217 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 222.
# extend_triple_array_by_one took 0.002300 second(s).
# extend_increasing_condition_by_one took 0.000431 second(s).
# extend_symbol_bound_by_one took 0.000237 second(s).
# AST of the assertion deductive contains 515 nodes.
# extend_deductive_condition_by_one took 0.008308 second(s).
# AST of the assertion ambiguity contains 570 nodes.
# build_ambiguity_condition took 0.007605 second(s).
# solve took 0.000696 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 414.
# extend_triple_array_by_one took 0.002542 second(s).
# extend_increasing_condition_by_one took 0.000412 second(s).
# extend_symbol_bound_by_one took 0.000197 second(s).
# AST of the assertion deductive contains 1150 nodes.
# extend_deductive_condition_by_one took 0.012309 second(s).
# AST of the assertion ambiguity contains 1478 nodes.
# build_ambiguity_condition took 0.015175 second(s).
# solve took 0.002808 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 660.
# extend_triple_array_by_one took 0.002839 second(s).
# extend_increasing_condition_by_one took 0.000355 second(s).
# extend_symbol_bound_by_one took 0.000196 second(s).
# AST of the assertion deductive contains 2138 nodes.
# extend_deductive_condition_by_one took 0.016480 second(s).
# AST of the assertion ambiguity contains 3042 nodes.
# build_ambiguity_condition took 0.027021 second(s).
# solve took 0.009591 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 960.
# extend_triple_array_by_one took 0.003327 second(s).
# extend_increasing_condition_by_one took 0.000441 second(s).
# extend_symbol_bound_by_one took 0.000234 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# AST of the assertion deductive contains 3555 nodes.
# extend_deductive_condition_by_one took 0.021381 second(s).
# AST of the assertion ambiguity contains 5430 nodes.
# build_ambiguity_condition took 0.070102 second(s).
# solve took 0.026580 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 1314.
# extend_triple_array_by_one took 0.003954 second(s).
# extend_increasing_condition_by_one took 0.000391 second(s).
# extend_symbol_bound_by_one took 0.000182 second(s).
# AST of the assertion deductive contains 5477 nodes.
# extend_deductive_condition_by_one took 0.026702 second(s).
# AST of the assertion ambiguity contains 8810 nodes.
# build_ambiguity_condition took 0.068482 second(s).
# solve took 0.060139 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 1722.
# extend_triple_array_by_one took 0.004121 second(s).
# extend_increasing_condition_by_one took 0.000418 second(s).
# extend_symbol_bound_by_one took 0.000251 second(s).
# AST of the assertion deductive contains 7980 nodes.
# extend_deductive_condition_by_one took 0.031857 second(s).
# AST of the assertion ambiguity contains 13350 nodes.
# build_ambiguity_condition took 0.098239 second(s).
# solve took 0.133147 second(s).
# Now checking witness sentences of length 8...
# SMT variable count is 2184.
# extend_triple_array_by_one took 0.042453 second(s).
# extend_increasing_condition_by_one took 0.000499 second(s).
# extend_symbol_bound_by_one took 0.000236 second(s).
# AST of the assertion deductive contains 11140 nodes.
# extend_deductive_condition_by_one took 0.038517 second(s).
# AST of the assertion ambiguity contains 19218 nodes.
# build_ambiguity_condition took 0.137864 second(s).
# solve took 0.258837 second(s).
# Now checking witness sentences of length 9...
# SMT variable count is 2700.
# extend_triple_array_by_one took 0.005025 second(s).
# extend_increasing_condition_by_one took 0.000481 second(s).
# extend_symbol_bound_by_one took 0.000225 second(s).
# AST of the assertion deductive contains 15033 nodes.
# extend_deductive_condition_by_one took 0.044295 second(s).
# AST of the assertion ambiguity contains 26582 nodes.
# build_ambiguity_condition took 0.230659 second(s).
# solve took 0.606198 second(s).
# Now checking witness sentences of length 10...
# SMT variable count is 3270.
# extend_triple_array_by_one took 0.005669 second(s).
# extend_increasing_condition_by_one took 0.000443 second(s).
# extend_symbol_bound_by_one took 0.000157 second(s).
# AST of the assertion deductive contains 19735 nodes.
# extend_deductive_condition_by_one took 0.052963 second(s).
# AST of the assertion ambiguity contains 35610 nodes.
# build_ambiguity_condition took 0.297024 second(s).
# solve took 1.047489 second(s).
# Now checking witness sentences of length 11...
# SMT variable count is 3894.
# extend_triple_array_by_one took 0.005722 second(s).
# extend_increasing_condition_by_one took 0.000463 second(s).
# extend_symbol_bound_by_one took 0.000189 second(s).
# AST of the assertion deductive contains 25322 nodes.
# extend_deductive_condition_by_one took 0.058855 second(s).
# AST of the assertion ambiguity contains 46470 nodes.
# build_ambiguity_condition took 0.385947 second(s).
# solve took 1.939461 second(s).
# Now checking witness sentences of length 12...
# SMT variable count is 4572.
# extend_triple_array_by_one took 0.006102 second(s).
# extend_increasing_condition_by_one took 0.000472 second(s).
# extend_symbol_bound_by_one took 0.000217 second(s).
# AST of the assertion deductive contains 31870 nodes.
# extend_deductive_condition_by_one took 0.086842 second(s).
# AST of the assertion ambiguity contains 59330 nodes.
# build_ambiguity_condition took 0.505416 second(s).
# solve took 3.342826 second(s).
# Now checking witness sentences of length 13...
# SMT variable count is 5304.
# extend_triple_array_by_one took 0.006602 second(s).
# extend_increasing_condition_by_one took 0.000584 second(s).
# extend_symbol_bound_by_one took 0.000189 second(s).
# AST of the assertion deductive contains 39455 nodes.
# extend_deductive_condition_by_one took 0.077840 second(s).
# AST of the assertion ambiguity contains 74358 nodes.
# build_ambiguity_condition took 0.638147 second(s).
# solve took 6.446130 second(s).
# Now checking witness sentences of length 14...
# SMT variable count is 6090.
# extend_triple_array_by_one took 0.006917 second(s).
# extend_increasing_condition_by_one took 0.000485 second(s).
# extend_symbol_bound_by_one took 0.000206 second(s).
# AST of the assertion deductive contains 48153 nodes.
# extend_deductive_condition_by_one took 0.192879 second(s).
# AST of the assertion ambiguity contains 91722 nodes.
# build_ambiguity_condition took 0.611920 second(s).
# solve took 8.968346 second(s).
# Now checking witness sentences of length 15...
# SMT variable count is 6930.
# extend_triple_array_by_one took 0.007214 second(s).
# extend_increasing_condition_by_one took 0.000482 second(s).
# extend_symbol_bound_by_one took 0.000241 second(s).
# AST of the assertion deductive contains 58040 nodes.
# extend_deductive_condition_by_one took 0.262260 second(s).
# AST of the assertion ambiguity contains 111590 nodes.
# build_ambiguity_condition took 0.713522 second(s).
# solve took 13.902186 second(s).
# Now checking witness sentences of length 16...
# SMT variable count is 7824.
# extend_triple_array_by_one took 0.007343 second(s).
# extend_increasing_condition_by_one took 0.000441 second(s).
# extend_symbol_bound_by_one took 0.000193 second(s).
# AST of the assertion deductive contains 69192 nodes.
# extend_deductive_condition_by_one took 0.257932 second(s).
# AST of the assertion ambiguity contains 134130 nodes.
# build_ambiguity_condition took 0.853557 second(s).
# solve took 23.643928 second(s).
# Now checking witness sentences of length 17...
# SMT variable count is 8772.
# extend_triple_array_by_one took 0.007883 second(s).
# extend_increasing_condition_by_one took 0.000441 second(s).
# extend_symbol_bound_by_one took 0.000180 second(s).
# AST of the assertion deductive contains 81685 nodes.
# extend_deductive_condition_by_one took 0.113790 second(s).
# AST of the assertion ambiguity contains 159510 nodes.
# build_ambiguity_condition took 1.231830 second(s).
# solve took 40.786651 second(s).
# Now checking witness sentences of length 18...
# SMT variable count is 9774.
# extend_triple_array_by_one took 0.008184 second(s).
# extend_increasing_condition_by_one took 0.000580 second(s).
# extend_symbol_bound_by_one took 0.000237 second(s).
# AST of the assertion deductive contains 95595 nodes.
# extend_deductive_condition_by_one took 0.123893 second(s).
# AST of the assertion ambiguity contains 187898 nodes.
# build_ambiguity_condition took 1.422225 second(s).
# solve took 61.174702 second(s).
# Now checking witness sentences of length 19...
# SMT variable count is 10830.
# extend_triple_array_by_one took 0.008560 second(s).
# extend_increasing_condition_by_one took 0.000472 second(s).
# extend_symbol_bound_by_one took 0.000190 second(s).
# AST of the assertion deductive contains 110998 nodes.
# extend_deductive_condition_by_one took 0.132914 second(s).
# AST of the assertion ambiguity contains 219462 nodes.
# build_ambiguity_condition took 1.636971 second(s).
# solve took 103.737388 second(s).
# Now checking witness sentences of length 20...
# SMT variable count is 11940.
# extend_triple_array_by_one took 0.009122 second(s).
# extend_increasing_condition_by_one took 0.000547 second(s).
# extend_symbol_bound_by_one took 0.000196 second(s).
# AST of the assertion deductive contains 127970 nodes.
# extend_deductive_condition_by_one took 0.153932 second(s).
# AST of the assertion ambiguity contains 254370 nodes.
# build_ambiguity_condition took 1.991744 second(s).
# solve took 182.964792 second(s).
# False
# 0402 let-stmt
# Now checking witness sentences of length 1...
# SMT variable count is 69.
# extend_triple_array_by_one took 0.001813 second(s).
# extend_increasing_condition_by_one took 0.005534 second(s).
# extend_symbol_bound_by_one took 0.000234 second(s).
# AST of the assertion deductive contains 124 nodes.
# extend_deductive_condition_by_one took 0.004361 second(s).
# AST of the assertion ambiguity contains 135 nodes.
# build_ambiguity_condition took 0.002948 second(s).
# solve took 0.000172 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 182.
# extend_triple_array_by_one took 0.002027 second(s).
# extend_increasing_condition_by_one took 0.000377 second(s).
# extend_symbol_bound_by_one took 0.000212 second(s).
# AST of the assertion deductive contains 417 nodes.
# extend_deductive_condition_by_one took 0.006749 second(s).
# AST of the assertion ambiguity contains 467 nodes.
# build_ambiguity_condition took 0.006227 second(s).
# solve took 0.000401 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 339.
# extend_triple_array_by_one took 0.002279 second(s).
# extend_increasing_condition_by_one took 0.000413 second(s).
# extend_symbol_bound_by_one took 0.000210 second(s).
# AST of the assertion deductive contains 948 nodes.
# extend_deductive_condition_by_one took 0.010168 second(s).
# AST of the assertion ambiguity contains 1200 nodes.
# build_ambiguity_condition took 0.012724 second(s).
# solve took 0.001253 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 540.
# extend_triple_array_by_one took 0.002598 second(s).
# extend_increasing_condition_by_one took 0.000359 second(s).
# extend_symbol_bound_by_one took 0.000217 second(s).
# AST of the assertion deductive contains 1786 nodes.
# extend_deductive_condition_by_one took 0.013652 second(s).
# AST of the assertion ambiguity contains 2478 nodes.
# build_ambiguity_condition took 0.022622 second(s).
# solve took 0.004173 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 785.
# extend_triple_array_by_one took 0.002839 second(s).
# extend_increasing_condition_by_one took 0.000424 second(s).
# extend_symbol_bound_by_one took 0.000187 second(s).
# AST of the assertion deductive contains 3000 nodes.
# extend_deductive_condition_by_one took 0.017910 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# AST of the assertion ambiguity contains 4445 nodes.
# build_ambiguity_condition took 0.063215 second(s).
# solve took 0.013311 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 1074.
# extend_triple_array_by_one took 0.003542 second(s).
# extend_increasing_condition_by_one took 0.000404 second(s).
# extend_symbol_bound_by_one took 0.000184 second(s).
# AST of the assertion deductive contains 4659 nodes.
# extend_deductive_condition_by_one took 0.022040 second(s).
# AST of the assertion ambiguity contains 7245 nodes.
# build_ambiguity_condition took 0.056455 second(s).
# solve took 0.030177 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 1407.
# extend_triple_array_by_one took 0.003497 second(s).
# extend_increasing_condition_by_one took 0.000443 second(s).
# extend_symbol_bound_by_one took 0.000231 second(s).
# AST of the assertion deductive contains 6832 nodes.
# extend_deductive_condition_by_one took 0.026903 second(s).
# AST of the assertion ambiguity contains 11022 nodes.
# build_ambiguity_condition took 0.082557 second(s).
# solve took 0.057806 second(s).
# Found a witness sentence, continue to check if it's a false positive.
# AST of the assertion sentence reachable contains 8147 nodes.
# build_reachable_condition took 0.094418 second(s).
# solve took 0.004495 second(s).
# Now checking witness sentences of length 8...
# SMT variable count is 1784.
# extend_triple_array_by_one took 0.005063 second(s).
# extend_increasing_condition_by_one took 0.000417 second(s).
# extend_symbol_bound_by_one took 0.000194 second(s).
# AST of the assertion deductive contains 9588 nodes.
# extend_deductive_condition_by_one took 0.031346 second(s).
# AST of the assertion ambiguity contains 15920 nodes.
# build_ambiguity_condition took 0.150219 second(s).
# solve took 0.122597 second(s).
# Found a witness sentence, continue to check if it's a false positive.
# AST of the assertion sentence reachable contains 11587 nodes.
# build_reachable_condition took 0.092251 second(s).
# solve took 0.007838 second(s).
# Now checking witness sentences of length 9...
# SMT variable count is 2205.
# extend_triple_array_by_one took 0.004210 second(s).
# extend_increasing_condition_by_one took 0.000468 second(s).
# extend_symbol_bound_by_one took 0.000183 second(s).
# AST of the assertion deductive contains 12996 nodes.
# extend_deductive_condition_by_one took 0.038704 second(s).
# AST of the assertion ambiguity contains 22083 nodes.
# build_ambiguity_condition took 0.204094 second(s).
# solve took 0.201187 second(s).
# Found a witness sentence, continue to check if it's a false positive.
# AST of the assertion sentence reachable contains 15872 nodes.
# build_reachable_condition took 0.111459 second(s).
# solve took 0.007917 second(s).
# Now checking witness sentences of length 10...
# SMT variable count is 2670.
# extend_triple_array_by_one took 0.004538 second(s).
# extend_increasing_condition_by_one took 0.000405 second(s).
# extend_symbol_bound_by_one took 0.000169 second(s).
# AST of the assertion deductive contains 17125 nodes.
# extend_deductive_condition_by_one took 0.044904 second(s).
# AST of the assertion ambiguity contains 29655 nodes.
# build_ambiguity_condition took 0.262442 second(s).
# solve took 0.343275 second(s).
# Found a witness sentence, continue to check if it's a false positive.
# AST of the assertion sentence reachable contains 21094 nodes.
# build_reachable_condition took 0.137515 second(s).
# solve took 0.019087 second(s).
# Ambiguous sentence of length 10 found.
# True
# 0402 haskell-do
# Now checking witness sentences of length 1...
# SMT variable count is 60.
# extend_triple_array_by_one took 0.001740 second(s).
# extend_increasing_condition_by_one took 0.005191 second(s).
# extend_symbol_bound_by_one took 0.000233 second(s).
# AST of the assertion deductive contains 105 nodes.
# extend_deductive_condition_by_one took 0.004072 second(s).
# AST of the assertion ambiguity contains 126 nodes.
# build_ambiguity_condition took 0.002667 second(s).
# solve took 0.000192 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 158.
# extend_triple_array_by_one took 0.001857 second(s).
# extend_increasing_condition_by_one took 0.000330 second(s).
# extend_symbol_bound_by_one took 0.000176 second(s).
# AST of the assertion deductive contains 353 nodes.
# extend_deductive_condition_by_one took 0.005982 second(s).
# AST of the assertion ambiguity contains 378 nodes.
# build_ambiguity_condition took 0.005399 second(s).
# solve took 0.000355 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 294.
# extend_triple_array_by_one took 0.002146 second(s).
# extend_increasing_condition_by_one took 0.000361 second(s).
# extend_symbol_bound_by_one took 0.000175 second(s).
# AST of the assertion deductive contains 802 nodes.
# extend_deductive_condition_by_one took 0.008773 second(s).
# AST of the assertion ambiguity contains 960 nodes.
# build_ambiguity_condition took 0.010960 second(s).
# solve took 0.001193 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 468.
# extend_triple_array_by_one took 0.002382 second(s).
# extend_increasing_condition_by_one took 0.000366 second(s).
# extend_symbol_bound_by_one took 0.000211 second(s).
# AST of the assertion deductive contains 1510 nodes.
# extend_deductive_condition_by_one took 0.012095 second(s).
# AST of the assertion ambiguity contains 2000 nodes.
# build_ambiguity_condition took 0.018829 second(s).
# solve took 0.003673 second(s).
# ...
# solve took 0.000364 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 279.
# extend_triple_array_by_one took 0.002100 second(s).
# extend_increasing_condition_by_one took 0.000371 second(s).
# extend_symbol_bound_by_one took 0.000266 second(s).
# AST of the assertion deductive contains 752 nodes.
# extend_deductive_condition_by_one took 0.009313 second(s).
# AST of the assertion ambiguity contains 960 nodes.
# build_ambiguity_condition took 0.010639 second(s).
# solve took 0.001212 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 444.
# extend_triple_array_by_one took 0.002349 second(s).
# extend_increasing_condition_by_one took 0.000388 second(s).
# extend_symbol_bound_by_one took 0.000195 second(s).
# AST of the assertion deductive contains 1420 nodes.
# extend_deductive_condition_by_one took 0.011651 second(s).
# AST of the assertion ambiguity contains 2036 nodes.
# build_ambiguity_condition took 0.018323 second(s).
# solve took 0.003330 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 645.
# extend_triple_array_by_one took 0.002539 second(s).
# extend_increasing_condition_by_one took 0.000390 second(s).
# extend_symbol_bound_by_one took 0.000246 second(s).
# AST of the assertion deductive contains 2390 nodes.
# extend_deductive_condition_by_one took 0.014926 second(s).
# AST of the assertion ambiguity contains 3737 nodes.
# build_ambiguity_condition took 0.029779 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# solve took 0.009877 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 882.
# extend_triple_array_by_one took 0.003069 second(s).
# extend_increasing_condition_by_one took 0.000443 second(s).
# extend_symbol_bound_by_one took 0.000214 second(s).
# AST of the assertion deductive contains 3718 nodes.
# extend_deductive_condition_by_one took 0.019760 second(s).
# AST of the assertion ambiguity contains 6203 nodes.
# build_ambiguity_condition took 0.045933 second(s).
# solve took 0.021286 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 1155.
# extend_triple_array_by_one took 0.002993 second(s).
# extend_increasing_condition_by_one took 0.000372 second(s).
# extend_symbol_bound_by_one took 0.000197 second(s).
# AST of the assertion deductive contains 5460 nodes.
# extend_deductive_condition_by_one took 0.022509 second(s).
# AST of the assertion ambiguity contains 9574 nodes.
# build_ambiguity_condition took 0.067201 second(s).
# solve took 0.048144 second(s).
# Found a witness sentence, continue to check if it's a false positive.
# AST of the assertion sentence reachable contains 7028 nodes.
# build_reachable_condition took 0.077940 second(s).
# solve took 0.004682 second(s).
# Ambiguous sentence of length 7 found.
# True
# 0304 where-assign
# Now checking witness sentences of length 1...
# SMT variable count is 81.
# extend_triple_array_by_one took 0.001877 second(s).
# extend_increasing_condition_by_one took 0.005314 second(s).
# extend_symbol_bound_by_one took 0.000275 second(s).
# AST of the assertion deductive contains 146 nodes.
# extend_deductive_condition_by_one took 0.004822 second(s).
# AST of the assertion ambiguity contains 124 nodes.
# build_ambiguity_condition took 0.002958 second(s).
# solve took 0.000161 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 214.
# extend_triple_array_by_one took 0.002189 second(s).
# extend_increasing_condition_by_one took 0.000360 second(s).
# extend_symbol_bound_by_one took 0.000159 second(s).
# AST of the assertion deductive contains 502 nodes.
# extend_deductive_condition_by_one took 0.007776 second(s).
# AST of the assertion ambiguity contains 401 nodes.
# build_ambiguity_condition took 0.006224 second(s).
# solve took 0.000211 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 399.
# extend_triple_array_by_one took 0.002431 second(s).
# extend_increasing_condition_by_one took 0.000394 second(s).
# extend_symbol_bound_by_one took 0.000207 second(s).
# AST of the assertion deductive contains 1156 nodes.
# extend_deductive_condition_by_one took 0.011600 second(s).
# AST of the assertion ambiguity contains 1087 nodes.
# build_ambiguity_condition took 0.012606 second(s).
# solve took 0.000843 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 636.
# extend_triple_array_by_one took 0.002884 second(s).
# extend_increasing_condition_by_one took 0.000377 second(s).
# extend_symbol_bound_by_one took 0.000196 second(s).
# AST of the assertion deductive contains 2196 nodes.
# extend_deductive_condition_by_one took 0.016360 second(s).
# AST of the assertion ambiguity contains 2350 nodes.
# build_ambiguity_condition took 0.023026 second(s).
# solve took 0.002686 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 925.
# extend_triple_array_by_one took 0.003106 second(s).
# extend_increasing_condition_by_one took 0.000404 second(s).
# extend_symbol_bound_by_one took 0.000162 second(s).
# AST of the assertion deductive contains 3710 nodes.
# extend_deductive_condition_by_one took 0.021053 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# AST of the assertion ambiguity contains 4358 nodes.
# build_ambiguity_condition took 0.066360 second(s).
# solve took 0.007601 second(s).
# Now checking witness sentences of length 6...
# SMT variable count is 1266.
# extend_triple_array_by_one took 0.003579 second(s).
# extend_increasing_condition_by_one took 0.000379 second(s).
# extend_symbol_bound_by_one took 0.000176 second(s).
# AST of the assertion deductive contains 5786 nodes.
# extend_deductive_condition_by_one took 0.027588 second(s).
# AST of the assertion ambiguity contains 7279 nodes.
# build_ambiguity_condition took 0.059876 second(s).
# solve took 0.022010 second(s).
# Now checking witness sentences of length 7...
# SMT variable count is 1659.
# extend_triple_array_by_one took 0.004143 second(s).
# extend_increasing_condition_by_one took 0.000485 second(s).
# extend_symbol_bound_by_one took 0.000216 second(s).
# AST of the assertion deductive contains 8512 nodes.
# extend_deductive_condition_by_one took 0.033216 second(s).
# AST of the assertion ambiguity contains 11281 nodes.
# build_ambiguity_condition took 0.095914 second(s).
# solve took 0.049033 second(s).
# Now checking witness sentences of length 8...
# SMT variable count is 2104.
# extend_triple_array_by_one took 0.004890 second(s).
# extend_increasing_condition_by_one took 0.000469 second(s).
# extend_symbol_bound_by_one took 0.000200 second(s).
# AST of the assertion deductive contains 11976 nodes.
# extend_deductive_condition_by_one took 0.040889 second(s).
# AST of the assertion ambiguity contains 16532 nodes.
# build_ambiguity_condition took 0.164328 second(s).
# solve took 0.092402 second(s).
# Now checking witness sentences of length 9...
# SMT variable count is 2601.
# extend_triple_array_by_one took 0.004987 second(s).
# extend_increasing_condition_by_one took 0.000499 second(s).
# extend_symbol_bound_by_one took 0.000168 second(s).
# AST of the assertion deductive contains 16266 nodes.
# extend_deductive_condition_by_one took 0.046548 second(s).
# AST of the assertion ambiguity contains 23200 nodes.
# build_ambiguity_condition took 0.171324 second(s).
# solve took 0.153473 second(s).
# Now checking witness sentences of length 10...
# SMT variable count is 3150.
# extend_triple_array_by_one took 0.005173 second(s).
# extend_increasing_condition_by_one took 0.000489 second(s).
# extend_symbol_bound_by_one took 0.000204 second(s).
# AST of the assertion deductive contains 21470 nodes.
# extend_deductive_condition_by_one took 0.052504 second(s).
# AST of the assertion ambiguity contains 31453 nodes.
# build_ambiguity_condition took 0.228380 second(s).
# solve took 0.273221 second(s).
# Now checking witness sentences of length 11...
# SMT variable count is 3751.
# extend_triple_array_by_one took 0.005400 second(s).
# extend_increasing_condition_by_one took 0.000446 second(s).
# extend_symbol_bound_by_one took 0.000185 second(s).
# AST of the assertion deductive contains 27676 nodes.
# extend_deductive_condition_by_one took 0.063140 second(s).
# AST of the assertion ambiguity contains 41459 nodes.
# build_ambiguity_condition took 0.364542 second(s).
# solve took 0.439943 second(s).
# Now checking witness sentences of length 12...
# SMT variable count is 4404.
# extend_triple_array_by_one took 0.005947 second(s).
# extend_increasing_condition_by_one took 0.000496 second(s).
# extend_symbol_bound_by_one took 0.000199 second(s).
# AST of the assertion deductive contains 34972 nodes.
# extend_deductive_condition_by_one took 0.072756 second(s).
# AST of the assertion ambiguity contains 53386 nodes.
# build_ambiguity_condition took 0.436953 second(s).
# solve took 0.712719 second(s).
# Now checking witness sentences of length 13...
# SMT variable count is 5109.
# extend_triple_array_by_one took 0.006278 second(s).
# extend_increasing_condition_by_one took 0.000481 second(s).
# extend_symbol_bound_by_one took 0.000214 second(s).
# AST of the assertion deductive contains 43446 nodes.
# extend_deductive_condition_by_one took 0.077435 second(s).
# AST of the assertion ambiguity contains 67402 nodes.
# build_ambiguity_condition took 0.553194 second(s).
# solve took 0.996057 second(s).
# Now checking witness sentences of length 14...
# SMT variable count is 5866.
# extend_triple_array_by_one took 0.007111 second(s).
# extend_increasing_condition_by_one took 0.000526 second(s).
# extend_symbol_bound_by_one took 0.000242 second(s).
# AST of the assertion deductive contains 53186 nodes.
# extend_deductive_condition_by_one took 0.117360 second(s).
# AST of the assertion ambiguity contains 83675 nodes.
# build_ambiguity_condition took 0.682885 second(s).
# solve took 1.504472 second(s).
# Now checking witness sentences of length 15...
# SMT variable count is 6675.
# extend_triple_array_by_one took 0.006786 second(s).
# extend_increasing_condition_by_one took 0.000460 second(s).
# extend_symbol_bound_by_one took 0.000238 second(s).
# AST of the assertion deductive contains 64280 nodes.
# extend_deductive_condition_by_one took 0.094639 second(s).
# AST of the assertion ambiguity contains 102373 nodes.
# build_ambiguity_condition took 0.811538 second(s).
# solve took 2.411124 second(s).
# Now checking witness sentences of length 16...
# SMT variable count is 7536.
# extend_triple_array_by_one took 0.007684 second(s).
# extend_increasing_condition_by_one took 0.000448 second(s).
# extend_symbol_bound_by_one took 0.000196 second(s).
# AST of the assertion deductive contains 76816 nodes.
# extend_deductive_condition_by_one took 0.106210 second(s).
# AST of the assertion ambiguity contains 123664 nodes.
# build_ambiguity_condition took 0.951961 second(s).
# solve took 3.307592 second(s).
# Now checking witness sentences of length 17...
# SMT variable count is 8449.
# extend_triple_array_by_one took 0.007797 second(s).
# extend_increasing_condition_by_one took 0.000543 second(s).
# extend_symbol_bound_by_one took 0.000181 second(s).
# AST of the assertion deductive contains 90882 nodes.
# extend_deductive_condition_by_one took 0.113660 second(s).
# AST of the assertion ambiguity contains 147716 nodes.
# build_ambiguity_condition took 1.167144 second(s).
# solve took 4.823875 second(s).
# Now checking witness sentences of length 18...
# SMT variable count is 9414.
# extend_triple_array_by_one took 0.008021 second(s).
# extend_increasing_condition_by_one took 0.000463 second(s).
# extend_symbol_bound_by_one took 0.000186 second(s).
# AST of the assertion deductive contains 106566 nodes.
# extend_deductive_condition_by_one took 0.128657 second(s).
# AST of the assertion ambiguity contains 174697 nodes.
# build_ambiguity_condition took 1.357723 second(s).
# solve took 6.246285 second(s).
# Now checking witness sentences of length 19...
# SMT variable count is 10431.
# extend_triple_array_by_one took 0.008318 second(s).
# extend_increasing_condition_by_one took 0.000522 second(s).
# extend_symbol_bound_by_one took 0.000175 second(s).
# AST of the assertion deductive contains 123956 nodes.
# extend_deductive_condition_by_one took 0.138129 second(s).
# AST of the assertion ambiguity contains 204775 nodes.
# build_ambiguity_condition took 1.608959 second(s).
# solve took 8.192635 second(s).
# Now checking witness sentences of length 20...
# SMT variable count is 11500.
# extend_triple_array_by_one took 0.008977 second(s).
# extend_increasing_condition_by_one took 0.000488 second(s).
# extend_symbol_bound_by_one took 0.000166 second(s).
# AST of the assertion deductive contains 143140 nodes.
# extend_deductive_condition_by_one took 0.146783 second(s).
# AST of the assertion ambiguity contains 238118 nodes.
# build_ambiguity_condition took 1.509799 second(s).
# solve took 10.577691 second(s).
# False
# 0304 python-while-list
# Now checking witness sentences of length 1...
# SMT variable count is 135.
# extend_triple_array_by_one took 0.002360 second(s).
# extend_increasing_condition_by_one took 0.005348 second(s).
# extend_symbol_bound_by_one took 0.000287 second(s).
# AST of the assertion deductive contains 254 nodes.
# extend_deductive_condition_by_one took 0.007282 second(s).
# AST of the assertion ambiguity contains 316 nodes.
# build_ambiguity_condition took 0.005323 second(s).
# solve took 0.000389 second(s).
# Now checking witness sentences of length 2...
# SMT variable count is 358.
# extend_triple_array_by_one took 0.002811 second(s).
# extend_increasing_condition_by_one took 0.000366 second(s).
# extend_symbol_bound_by_one took 0.000166 second(s).
# AST of the assertion deductive contains 824 nodes.
# extend_deductive_condition_by_one took 0.012546 second(s).
# AST of the assertion ambiguity contains 1006 nodes.
# build_ambiguity_condition took 0.011812 second(s).
# solve took 0.001359 second(s).
# Now checking witness sentences of length 3...
# SMT variable count is 669.
# extend_triple_array_by_one took 0.003272 second(s).
# extend_increasing_condition_by_one took 0.000358 second(s).
# extend_symbol_bound_by_one took 0.000176 second(s).
# AST of the assertion deductive contains 1820 nodes.
# extend_deductive_condition_by_one took 0.018338 second(s).
# AST of the assertion ambiguity contains 2436 nodes.
# build_ambiguity_condition took 0.025144 second(s).
# solve took 0.005559 second(s).
# Now checking witness sentences of length 4...
# SMT variable count is 1068.
# extend_triple_array_by_one took 0.004116 second(s).
# extend_increasing_condition_by_one took 0.000522 second(s).
# extend_symbol_bound_by_one took 0.000248 second(s).
# AST of the assertion deductive contains 3352 nodes.
# extend_deductive_condition_by_one took 0.027020 second(s).
# /home/panda2134/.local/share/virtualenvs/smt-disambig--ZMk3Rpv/lib/python3.10/site-packages/pysmt/oracles.py:71: UserWarning: Instance-based walkers (<=0.6.0) walkers are deprecated. You should use new-style/class based walkers
#   self.set_function(self.measure_to_fun[measure], *op.ALL_TYPES)
# AST of the assertion ambiguity contains 4850 nodes.
# build_ambiguity_condition took 0.080519 second(s).
# solve took 0.018748 second(s).
# Now checking witness sentences of length 5...
# SMT variable count is 1555.
# extend_triple_array_by_one took 0.004711 second(s).
# extend_increasing_condition_by_one took 0.000533 second(s).
# extend_symbol_bound_by_one took 0.000240 second(s).
# AST of the assertion deductive contains 5530 nodes.
# extend_deductive_condition_by_one took 0.037984 second(s).
# AST of the assertion ambiguity contains 8492 nodes.
# build_ambiguity_condition took 0.083596 second(s).
# solve took 0.047425 second(s).
# Found a witness sentence, continue to check if it's a false positive.
# AST of the assertion sentence reachable contains 6189 nodes.
# build_reachable_condition took 0.088144 second(s).
# solve took 0.003636 second(s).
# Ambiguous sentence of length 5 found.
# True

# %%
sum(ambig), len(ambig)
# Out:
# (6, 32)

# %% [markdown]
# There're 6 out of 32 ambiguous results in manual cases.

# %%
list(filter(lambda x: x[1], zip(manual_results, ambig)))
# Out:
# [(('0402',
#    'let-stmt',
#    '__JA3KhnErDU8J5_rRcEGrr',
#    datetime.timedelta(seconds=557)),
#   True),
#  (('0402',
#    'haskell-do',
#    '__oiONQO1rKV-enKQX2LgzM',
#    datetime.timedelta(seconds=152)),
#   True),
#  (('0402',
#    'where-assign',
#    '__pgodrfWWoS3QIanDpQIj1',
#    datetime.timedelta(seconds=94)),
#   True),
#  (('0403',
#    'yaml-map',
#    '__b_ajbentO29f3gos2kZNr',
#    datetime.timedelta(seconds=415)),
#   True),
#  (('0304',
#    'haskell-do',
#    '__Zsdc-OdhGXMW9PKNarEcx',
#    datetime.timedelta(seconds=181)),
#   True),
#  (('0304',
#    'python-while-list',
#    '__3v0AYkpOGXgqGOnY0Ie1H',
#    datetime.timedelta(seconds=402)),
#   True)]

# %% [markdown]
# #### P2, 0402, let-stmt, B2
#
# ```
# let-expr ::= ( ( ( "let"   decl |*|  ) >> )  "in"  expr  ) >> ;
# decl ::= (  expr  "="  expr  ) >> ;
# expr ::= "id" | ( "id"  "id"  ) >> | let-expr;
# ```
#
# #### P2, 0402, haskell-do, B4
#
# ```
# document ::= stmt |+| ;
# do-block ::= ( "do"  stmt |+| ) >> ;
# stmt ::= ( ( "main"  "="  do-block  ) >> ) | ( "putStrLn"  "id"  ) >>;
# ```
#
# #### P2, 0402, where-assign, B6
#
# ```
# document ::= assign-stmt |+|;
# assign-stmt ::= ( ( ( "id"  "="  expr  ) >> )  (  where ? )  ) >> ;
# where ::= ( "where" assign-stmt |+|  ) >> ;
# expr ::= ( "id"  "+"  "id"  ) ~ ;
# ```
#
# #### P3, 0403, yaml-map, B7
#
# ```
# map ::= ( ( "id"  ":"  ) ~   map-body  )|>;
# map-body ::= expl-or-impl-kv |+|;
# expl-kv ::= ( expl-k  expl-v?)|>;
# expl-k ::= ( "?"  k-or-v  ) >> ;
# expl-v ::= ( ":"  k-or-v  ) >> ;
# impl-kv ::= ( ( "id"  ":"  ) ~   "id"? ) ~ ;
# k-or-v ::= ( ( map-body | "id"  ) >> ) ? ;
# expl-or-impl-kv ::= expl-kv | impl-kv ;
# ```
#
# #### P8, 0304, haskell-do, B4
#
# ```
# document ::= stmt |+|;
# do-block ::= "do" -> (  stmt + );
# stmt ::= (  ( "main"  "="  )>>   do-block ) | ( "putStrLn"  "id"  )>>  ;
# ```
#
# #### P8, 0304, python-while-list, B8
#
# ```
# document ::=  stmt |+| ;
# stmt ::= "pass" | while-stmt | decl ;
# while-head ::= ( ( ( "while"  "True"  ) ~ )  ":"  ) ~ ;
# while-body-stmt ::= ( stmt | "break"  )>>;
# while-stmt ::= ( while-head  (  while-body-stmt + )  ) >> ;
# decl ::= ident  "="  list ;
# ident ::= ( "foo" | "bar"  | "baz" ) ~ ;
# list ::= ( (  "["   ( ( ident  ","  ) ~ ) *  ident  )>> "]"  )>>;
# ```

# %% [markdown]
# #### Inspection
#
# - 0401
#     - python-for: not enforcing sameline
# - 0402
#     - python-while-list: decl >>, too strict
#     - other 3 are ambiguous
# - 0403
#     - yaml-list: wrong. disallows cascading
#     - yaml-map: ambiguous
# - 0404
#     - all: excessive constraints
# - 0304
#     - let-stmt: too strict; contradicting constraints
#     - where-assign: too strict; contradicting constraints
#     - python-while-list: ambiguous

# %% [markdown]
# ### Disambiguation Time

# %%
from collections import defaultdict
from datetime import timedelta

manual_time_sum = defaultdict(list)

for k, v in map(lambda x: (x[1], x[3]), manual_results):
    manual_time_sum[k].append(v)

# %%
from statistics import *
from datetime import timedelta
from prettytable import PrettyTable

tbl_manual = PrettyTable()
tbl_manual.field_names = ["Grammar", "Average", "Median"]
tbl_manual.align = 'l'
tbl_manual.align['avg'] = tbl_manual.align['median'] = 'c'

for k in exp_list:
    v = manual_time_sum[k]
    tbl_manual.add_row([k, timedelta(seconds=int(fmean(map(lambda x: x.seconds, v)))), timedelta(seconds=int(median(v).seconds))])

print("Time for manual disambiguation of grammars")
print(tbl_manual)
# Out:
# Time for manual disambiguation of grammars
# +-------------------+---------+---------+
# | Grammar           | Average | Median  |
# +-------------------+---------+---------+
# | yaml-list         | 0:02:25 | 0:02:07 |
# | let-stmt          | 0:06:45 | 0:06:56 |
# | match-case        | 0:01:53 | 0:01:32 |
# | haskell-do        | 0:02:28 | 0:02:46 |
# | python-for        | 0:01:33 | 0:01:26 |
# | where-assign      | 0:02:35 | 0:02:29 |
# | yaml-map          | 0:05:11 | 0:04:55 |
# | python-while-list | 0:08:20 | 0:05:53 |
# +-------------------+---------+---------+

# %% [markdown]
# **TODO: REMOVE TIME IN SUPPLEMENTARY MATERIAL**

# %% [markdown]
# ### Automatic
#
# - collect disambiguation time & final results

# %%
auto_cases = list(map(lambda y: (y[0], y[1], exp_list[y[1]]), filter(lambda x: not is_manual(x[0], x[1]), itertools.product(users, range(8)))))

# %%
len(auto_cases)
# Out:
# 32

# %%
auto_results = []

for uid, case_id, case in auto_cases:
    #if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    #if uid == '0404' and case_id == 6: continue # failed case
    metrics = list(db.metricTool.find({
        "uid": uid,
        "createdAt": {"$gte": start_time},
        "grammar": {"$regex": r"^" + case + r"\[........\]_round_\d+$"}
    }).sort("createdAt", pymongo.ASCENDING).limit(1))
    first_metric = metrics[0]
    result_grammar = list(db.ebnf.find({
        "uid": uid,
        "grammarName": {"$regex": r"^" + case + r"\[........\]_round_\d+$"}
    }).sort("createdAt", pymongo.DESCENDING).limit(1))[0]
    auto_results.append((uid, case, result_grammar['grammarName'], result_grammar['createdAt'] - first_metric['createdAt']))

# %%
auto_results[0], len(auto_results)
# Out:
# (('0401',
#   'let-stmt',
#   'let-stmt[4JgUWjlB]_round_2',
#   datetime.timedelta(seconds=79)),
#  32)

# %%
auto_root = results_root / "auto"
auto_root.mkdir(exist_ok=True)

for uid, grammar, grammar_id, _ in auto_results:
    g = list(db.ebnf.find({"grammarName": grammar_id}).limit(1))[0]
    filename = f"{uid}_{grammar}.ebnf"
    b = auto_root / filename
    with b.open('w') as f:
        f.write(g['ebnf'])

# %%
# !ls "results/2022-06-04/auto/"
# Out:
# 0301_haskell-do.ebnf	     0401_haskell-do.ebnf
# 0301_let-stmt.ebnf	     0401_let-stmt.ebnf
# 0301_python-while-list.ebnf  0401_python-while-list.ebnf
# 0301_where-assign.ebnf	     0401_where-assign.ebnf
# 0302_match-case.ebnf	     0402_match-case.ebnf
# 0302_python-for.ebnf	     0402_python-for.ebnf
# 0302_yaml-list.ebnf	     0402_yaml-list.ebnf
# 0302_yaml-map.ebnf	     0402_yaml-map.ebnf
# 0303_haskell-do.ebnf	     0403_haskell-do.ebnf
# 0303_let-stmt.ebnf	     0403_let-stmt.ebnf
# 0303_python-while-list.ebnf  0403_python-while-list.ebnf
# 0303_where-assign.ebnf	     0403_where-assign.ebnf
# 0304_match-case.ebnf	     0404_match-case.ebnf
# 0304_python-for.ebnf	     0404_python-for.ebnf
# 0304_yaml-list.ebnf	     0404_yaml-list.ebnf
# 0304_yaml-map.ebnf	     0404_yaml-map.ebnf

# %%
from collections import defaultdict
from datetime import timedelta

auto_time_sum = defaultdict(list)

for k, v in map(lambda x: (x[1], x[3]), auto_results):
    auto_time_sum[k].append(v)

# %%
from statistics import *
from datetime import timedelta
from prettytable import PrettyTable

tbl_auto = PrettyTable()
tbl_auto.field_names = ["Grammar", "Average", "Median"]
tbl_auto.align = 'l'
tbl_auto.align['avg'] = tbl_auto.align['median'] = 'c'

for k in exp_list:
    v = auto_time_sum[k]
    tbl_auto.add_row([k, timedelta(seconds=int(fmean(map(lambda x: x.seconds, v)))), timedelta(seconds=int(median(v).seconds))])

print("Time for auto disambiguation of grammars")
print(tbl_auto)
# Out:
# Time for auto disambiguation of grammars
# +-------------------+---------+---------+
# | Grammar           | Average | Median  |
# +-------------------+---------+---------+
# | yaml-list         | 0:02:57 | 0:02:47 |
# | let-stmt          | 0:01:57 | 0:01:50 |
# | match-case        | 0:06:09 | 0:05:22 |
# | haskell-do        | 0:02:24 | 0:02:04 |
# | python-for        | 0:01:56 | 0:01:51 |
# | where-assign      | 0:03:54 | 0:03:42 |
# | yaml-map          | 0:11:02 | 0:08:24 |
# | python-while-list | 0:01:54 | 0:01:54 |
# +-------------------+---------+---------+

# %%
auto_time_sum['python-while-list']
# Out:
# [datetime.timedelta(seconds=119),
#  datetime.timedelta(seconds=110),
#  datetime.timedelta(seconds=61),
#  datetime.timedelta(seconds=167)]

# %%
sum(auto_time_sum['python-while-list'], start=timedelta(0)) / 4
# Out:
# datetime.timedelta(seconds=114, microseconds=250000)

# %% [markdown]
# #### Inspection
# - 0401
#     - let-stmt: too strict, excluding examples
# - 0402
#     - yaml-list: wrong. disallows cascading
# - 0403
#     - haskell-do: excessive constraints
#     - let-stmt: too strict, disallows cascading
#     - python-while-list: too strict, excluding examples
#     - where-assign: might be too strict, differs from examples given
# - 0404
#     - match-case: too weak? not requiring match -> cases
#     - python-for: exc. cons.
#     - yaml-list: exc. cons.
# - 0301
#     - where-assign: might be too strict, differs from examples given
# - 0303
#     - python-while-list: excluding examples
#     - where-assign: exc. cons.
# - 0304
#     - python-for: exc. cons.
#     - yaml-map: wrong. disallows cascading

# %% [markdown]
# #### Iteration Count

# %%
for uid, case_id, case in auto_cases:
    #if uid[1] == '3' and 2 <= case_id < 4: continue # skipped cases
    #if uid == '0404' and case_id == 6: continue # failed case
    grammars = list(db.ebnf.find({
        "uid": uid,
        "grammarName": {"$regex": r"^" + case + r"\[........\]_round_\d+$"}
    }).sort("createdAt", pymongo.ASCENDING))
    print(uid, case, len(grammars))
# Out:
# 0401 let-stmt 2
# 0401 haskell-do 3
# 0401 where-assign 3
# 0401 python-while-list 2
# 0402 yaml-list 3
# 0402 match-case 3
# 0402 python-for 2
# 0402 yaml-map 11
# 0403 let-stmt 2
# 0403 haskell-do 2
# 0403 where-assign 4
# 0403 python-while-list 2
# 0404 yaml-list 2
# 0404 match-case 3
# 0404 python-for 2
# 0404 yaml-map 8
# 0301 let-stmt 2
# 0301 haskell-do 2
# 0301 where-assign 2
# 0301 python-while-list 2
# 0302 yaml-list 2
# 0302 match-case 5
# 0302 python-for 2
# 0302 yaml-map 3
# 0303 let-stmt 2
# 0303 haskell-do 2
# 0303 where-assign 2
# 0303 python-while-list 2
# 0304 yaml-list 3
# 0304 match-case 2
# 0304 python-for 3
# 0304 yaml-map 5

# %% [markdown]
# ### Paper Writing
#
# #### time (?)
#
# - imperfect ui design?
# - iteration cnt?
#
# #### disambiguation
#
# - 5 / 28: effectiveness
# - questionaire results
#
# **Metrics on time are not accurate**

# %%
6/32
# Out:
# 0.1875
